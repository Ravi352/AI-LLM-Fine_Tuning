# %%
#write a function where you reverse the integer number by not making it string

a = "keerth"
def reverse(x):
  if isinstance(x,int):
    rever = 0
    temp =x
    while(temp>0):
      reminder = temp%10
      # print(reminder)
      rever = rever*10 + reminder
      temp = temp//10
      # print(temp)
    return rever
  else:
    return (x[::-1])
reverse(a)
# Out:
# 'anahtreek'

# %%
# Out:
# 1233455
# 123345
# 12334
# 1233
# 123
# 12
# 1
# 0
# 65543321
