# %%
# !pip install faiss-cpu==1.7.4 chromadb==0.3.21
# Out:
# Collecting faiss-cpu==1.7.4
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 57.3 MB/s eta 0:00:00
# Collecting chromadb==0.3.21
#   Downloading chromadb-0.3.21-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.5.3)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.10.13)
# Collecting hnswlib>=0.7 (from chromadb==0.3.21)
#   Downloading hnswlib-0.7.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clickhouse-connect>=0.5.7 (from chromadb==0.3.21)
#   Downloading clickhouse_connect-0.6.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.4/954.4 kB 28.7 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.2.2 (from chromadb==0.3.21)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: duckdb>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (0.8.1)
# Collecting fastapi>=0.85.1 (from chromadb==0.3.21)
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.9 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb==0.3.21)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.23.5)
# Collecting posthog>=2.4.0 (from chromadb==0.3.21)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2023.7.22)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2.0.7)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2023.3.post1)
# Collecting zstandard (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 81.1 MB/s eta 0:00:00
# Collecting lz4 (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.85.1->chromadb==0.3.21) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.85.1->chromadb==0.3.21)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.3 MB/s eta 0:00:00
# Collecting typing-extensions>=4.8.0 (from fastapi>=0.85.1->chromadb==0.3.21)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->chromadb==0.3.21) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.3.21) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (3.4)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 36.2 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 48.1 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.1 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.85.1->chromadb==0.3.21) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.85.1->chromadb==0.3.21) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 58.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.2->chromadb==0.3.21) (9.4.0)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=2.2.2->chromadb==0.3.21)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.3.0)
# Building wheels for collected packages: hnswlib, sentence-transformers
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.7.0-cp310-cp310-linux_x86_64.whl size=2202683 sha256=26fe085f3639268ec2be7e56f3aa10e3e71481ba27d4540928ddd0b366ee4c62
#   Stored in directory: /root/.cache/pip/wheels/8a/ae/ec/235a682e0041fbaeee389843670581ec6c66872db856dfa9a4
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=2320b11dd3fedfbfe4d51a8c6194b53ce5b579da10e9c3cea853b4557935a320
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built hnswlib sentence-transformers
# Installing collected packages: sentencepiece, monotonic, faiss-cpu, zstandard, websockets, uvloop, typing-extensions, safetensors, python-dotenv, lz4, httptools, hnswlib, h11, backoff, watchfiles, uvicorn, starlette, posthog, huggingface-hub, clickhouse-connect, tokenizers, fastapi, transformers, sentence-transformers, chromadb
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed backoff-2.2.1 chromadb-0.3.21 clickhouse-connect-0.6.18 faiss-cpu-1.7.4 fastapi-0.104.1 h11-0.14.0 hnswlib-0.7.0 httptools-0.6.1 huggingface-hub-0.17.3 lz4-4.3.2 monotonic-1.6 posthog-3.0.2 python-dotenv-1.0.0 safetensors-0.4.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 starlette-0.27.0 tokenizers-0.14.1 transformers-4.35.0 typing-extensions-4.8.0 uvicorn-0.23.2 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0 zstandard-0.22.0

# %%
import pandas as pd

pdf = pd.read_csv("/content/labelled_newscatcher_dataset.csv", sep=";")
pdf["id"] = pdf.index
display(pdf)
# Out:
#                topic                                               link  \
# 0            SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1            SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2            SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3            SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4            SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ...              ...                                                ...
# 14344     TECHNOLOGY  https://www.techradar.com/news/this-tiny-pc-is...
# 14345        SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 14346         HEALTH  https://www.thekashmirmonitor.net/young-people...
# 14347  ENTERTAINMENT  https://www.fool.com/investing/2020/08/05/3-th...
# 14348         HEALTH  https://www.dailytelegraph.com.au/subscribe/ne...
#
#                       domain       published_date  \
# 0             eurekalert.org  2020-08-06 13:59:45
# 1                   pulse.ng  2020-08-12 15:14:19
# 2              express.co.uk  2020-08-13 21:01:00
# 3                   ndtv.com  2020-08-03 22:18:26
# 4                  thesun.ie  2020-08-12 19:54:36
# ...                      ...                  ...
# 14344          techradar.com  2020-08-09 03:00:00
# 14345         eurekalert.org  2020-08-05 04:17:40
# 14346  thekashmirmonitor.net  2020-08-13 06:29:00
# 14347               fool.com  2020-08-05 12:10:00
# 14348                dailyte                  NaN
#
#                                                    title lang     id
# 0      A closer look at water-splitting's solar fuel ...   en      0
# 1      An irresistible scent makes locusts swarm, stu...   en      1
# 2      Artificial intelligence warning: AI will know ...   en      2
# 3       Glaciers Could Have Sculpted Mars Valleys: Study   en      3
# 4      Perseid meteor shower 2020: What time and how ...   en      4
# ...                                                  ...  ...    ...
# 14344  This tiny PC is barely bigger than a USB thumb...   en  14344
# 14345  Tracking humanity's latest toxins in stranded ...   en  14345
# 14346  Young people play important role in helping st...   en  14346
# 14347     3 Things Disney Isn't Likely to Ever Say Again   en  14347
# 14348                                                NaN  NaN  14348
#
# [14349 rows x 7 columns]

# %%
pdf.title.values
# Out:
# 14349

# %%
from sentence_transformers import InputExample

pdf_subset = pdf.head(1000)

def example_create_fn(doc1: pd.Series) -> InputExample:
    """
    Helper function that outputs a sentence_transformer guid, label, and text
    """
    return InputExample(texts=[doc1])

faiss_train_examples = pdf_subset.apply(
    lambda x: example_create_fn(x["title"]), axis=1
).tolist()

# %%
# !mkdir cache

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "all-MiniLM-L6-v2",
    cache_folder="../working/cache/"
)  # Use a pre-cached model
faiss_title_embedding = model.encode(pdf_subset.title.values.tolist())
len(faiss_title_embedding), len(faiss_title_embedding[0])
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# (1000, 384)

# %%
import numpy as np
import faiss

pdf_to_index = pdf_subset.set_index(["id"], drop=False)
id_index = np.array(pdf_to_index.id.values).flatten().astype("int")

content_encoded_normalized = faiss_title_embedding.copy()
faiss.normalize_L2(content_encoded_normalized)

# Index1DMap translates search results to IDs: https://faiss.ai/cpp_api/file/IndexIDMap_8h.html#_CPPv4I0EN5faiss18IndexIDMapTemplateE
# The IndexFlatIP below builds index
index_content = faiss.IndexIDMap(faiss.IndexFlatIP(len(faiss_title_embedding[0])))
index_content.add_with_ids(content_encoded_normalized, id_index)

# %%
def search_content(query, pdf_to_index, k=3):
    query_vector = model.encode([query])
    faiss.normalize_L2(query_vector)

    # We set k to limit the number of vectors we want to return
    top_k = index_content.search(query_vector, k)
    ids = top_k[1][0].tolist()
    similarities = top_k[0][0].tolist()
    results = pdf_to_index.loc[ids]
    results["similarities"] = similarities
    return results

# %%
display(search_content("animal", pdf_to_index))
# Out:
#           topic                                               link  \
# id
# 176  TECHNOLOGY  https://www.pushsquare.com/news/2020/08/random...
# 975      HEALTH  https://www.news-medical.net/news/20200813/Res...
# 99   TECHNOLOGY  https://www.gematsu.com/2020/08/ghostwire-toky...
#
#                domain       published_date  \
# id
# 176    pushsquare.com  2020-08-03 16:30:00
# 975  news-medical.net  2020-08-13 05:18:00
# 99        gematsu.com  2020-08-07 16:43:13
#
#                                                  title lang   id  similarities
# id
# 176  Random: You Can Pick Up and Pet Cats in Assass...   en  176      0.391902
# 975  Researchers explore social behavior of animals...   en  975      0.376784
# 99               Ghostwire: Tokyo confirms dog petting   en   99      0.344058

# %%
import chromadb
from chromadb.config import Settings

chroma_client = chromadb.Client(
    Settings(
        chroma_db_impl="duckdb+parquet",
        persist_directory="../working/cache/",  # this is an optional argument. If you don't supply this, the data will be ephemeral
    )
)
# Out:
# WARNING:chromadb:Using embedded DuckDB with persistence: data will be stored in: ../working/cache/

# %%
collection_name = "my_news"

# If you have created the collection before, you need delete the collection first
if len(chroma_client.list_collections()) > 0 and collection_name in [
    chroma_client.list_collections()[0].name
]:
    chroma_client.delete_collection(name=collection_name)
else:
    print(f"Creating collection: '{collection_name}'")
    collection = chroma_client.create_collection(name=collection_name)
# Out:
# WARNING:chromadb.api.models.Collection:No embedding_function provided, using default embedding function: SentenceTransformerEmbeddingFunction
# Creating collection: 'my_news'
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
display(pdf_subset)
# Out:
#           topic                                               link  \
# 0       SCIENCE  https://www.eurekalert.org/pub_releases/2020-0...
# 1       SCIENCE  https://www.pulse.ng/news/world/an-irresistibl...
# 2       SCIENCE  https://www.express.co.uk/news/science/1322607...
# 3       SCIENCE  https://www.ndtv.com/world-news/glaciers-could...
# 4       SCIENCE  https://www.thesun.ie/tech/5742187/perseid-met...
# ..          ...                                                ...
# 995  TECHNOLOGY  https://www.androidcentral.com/mate-40-will-be...
# 996     SCIENCE  https://www.cnn.com/2020/08/17/africa/stone-ag...
# 997      HEALTH  https://www.tenterfieldstar.com.au/story/68776...
# 998      HEALTH  https://news.sky.com/story/coronavirus-trials-...
# 999      HEALTH  https://www.techexplorist.com/study-demonstrat...
#
#                      domain       published_date  \
# 0            eurekalert.org  2020-08-06 13:59:45
# 1                  pulse.ng  2020-08-12 15:14:19
# 2             express.co.uk  2020-08-13 21:01:00
# 3                  ndtv.com  2020-08-03 22:18:26
# 4                 thesun.ie  2020-08-12 19:54:36
# ..                      ...                  ...
# 995      androidcentral.com  2020-08-07 17:12:33
# 996                 cnn.com  2020-08-17 17:10:00
# 997  tenterfieldstar.com.au  2020-08-13 03:26:06
# 998            news.sky.com  2020-08-13 13:22:58
# 999       techexplorist.com  2020-08-10 07:47:00
#
#                                                  title lang   id
# 0    A closer look at water-splitting's solar fuel ...   en    0
# 1    An irresistible scent makes locusts swarm, stu...   en    1
# 2    Artificial intelligence warning: AI will know ...   en    2
# 3     Glaciers Could Have Sculpted Mars Valleys: Study   en    3
# 4    Perseid meteor shower 2020: What time and how ...   en    4
# ..                                                 ...  ...  ...
# 995  The Mate 40 will be the last Huawei phone with...   en  995
# 996  Early humans knew how to make comfy, pest-free...   en  996
# 997           Regional Vic set for virus testing blitz   en  997
# 998  Coronavirus: Trials of second contact-tracing ...   en  998
# 999  The study demonstrates new treatment for prion...   en  999
#
# [1000 rows x 7 columns]

# %%
collection.add(
    documents=pdf_subset["title"][:100].tolist(),
    metadatas=[{"topic": topic} for topic in pdf_subset["topic"][:100].tolist()],
    ids=[f"id{x}" for x in range(100)],
)

# %%
import json

results = collection.query(query_texts=["space"], n_results=10)

print(json.dumps(results, indent=4))
# Out:
# {
#     "ids": [
#         [
#             "id72",
#             "id7",
#             "id30",
#             "id26",
#             "id23",
#             "id76",
#             "id69",
#             "id40",
#             "id47",
#             "id75"
#         ]
#     ],
#     "embeddings": null,
#     "documents": [
#         [
#             "Beck teams up with NASA and AI for 'Hyperspace' visual album experience",
#             "Orbital space tourism set for rebirth in 2021",
#             "NASA drops \"insensitive\" nicknames for cosmic objects",
#             "\u2018It came alive:\u2019 NASA astronauts describe experiencing splashdown in SpaceX Dragon",
#             "Hubble Uses Moon As \u201cMirror\u201d to Study Earth\u2019s Atmosphere \u2013 Proxy in Search of Potentially Habitable Planets Around Other Stars",
#             "Australia's small yet crucial part in the mission to find life on Mars",
#             "NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico",
#             "SpaceX's Starship spacecraft saw 150 meters high",
#             "NASA\u2019s InSight lander shows what\u2019s beneath Mars\u2019 surface",
#             "Alien base on Mercury: ET hunters claim to find huge UFO"
#         ]
#     ],
#     "metadatas": [
#         [
#             {
#                 "topic": "TECHNOLOGY"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             },
#             {
#                 "topic": "SCIENCE"
#             }
#         ]
#     ],
#     "distances": [
#         [
#             1.2250354290008545,
#             1.3089773654937744,
#             1.391038417816162,
#             1.4064621925354004,
#             1.4391300678253174,
#             1.4898791313171387,
#             1.5728247165679932,
#             1.5738130807876587,
#             1.5835301876068115,
#             1.5864628553390503
#         ]
#     ]
# }

# %%
collection.query(query_texts=["space"], where={"topic": "SCIENCE"}, n_results=10)
# Out:
# {'ids': [['id7',
#    'id30',
#    'id26',
#    'id23',
#    'id76',
#    'id69',
#    'id40',
#    'id47',
#    'id75',
#    'id52']],
#  'embeddings': None,
#  'documents': [['Orbital space tourism set for rebirth in 2021',
#    'NASA drops "insensitive" nicknames for cosmic objects',
#    '‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon',
#    'Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars',
#    "Australia's small yet crucial part in the mission to find life on Mars",
#    'NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico',
#    "SpaceX's Starship spacecraft saw 150 meters high",
#    'NASA’s InSight lander shows what’s beneath Mars’ surface',
#    'Alien base on Mercury: ET hunters claim to find huge UFO',
#    'SpaceX Crew-1 mission with NASA, first fully operational crewed mission to space to launch in October']],
#  'metadatas': [[{'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'},
#    {'topic': 'SCIENCE'}]],
#  'distances': [[1.3089773654937744,
#    1.391038417816162,
#    1.4064621925354004,
#    1.4391300678253174,
#    1.4898791313171387,
#    1.5728247165679932,
#    1.5738130807876587,
#    1.5835301876068115,
#    1.5864628553390503,
#    1.5984288454055786]]}

# %%
collection.delete(ids=["id0"])
# Out:
# [UUID('2a7c9da9-9e97-4995-97da-0d6eeb0e8cb9')]

# %%
collection.get(
    ids=["id0"],
)
# Out:
# {'ids': [], 'embeddings': None, 'documents': [], 'metadatas': []}

# %%
collection.get(
    ids=["id2"],
)
# Out:
# {'ids': ['id2'],
#  'embeddings': None,
#  'documents': ['Artificial intelligence warning: AI will know us better than we know ourselves'],
#  'metadatas': [{'topic': 'SCIENCE'}]}

# %%
collection.update(
    ids=["id2"],
    metadatas=[{"topic": "TECHNOLOGY"}],
)

# %%
collection.get(
    ids=["id2"],
)
# Out:
# {'ids': ['id2'],
#  'embeddings': None,
#  'documents': ['Artificial intelligence warning: AI will know us better than we know ourselves'],
#  'metadatas': [{'topic': 'TECHNOLOGY'}]}

# %%
# !pip install --upgrade accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.8.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.24.1

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id, cache_dir="../working/cache/")
lm_model = AutoModelForCausalLM.from_pretrained(model_id, cache_dir="../working/cache/")

pipe = pipeline(
    "text-generation",
    model=lm_model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    device_map="auto",
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
question = "What's the latest news on space development?"
context = " ".join([f"#{str(i)}" for i in results["documents"][0]])
prompt_template = f"Relevant context: {context}\n\n The user's question: {question}"

# %%
context
# Out:
# '#Beck teams up with NASA and AI for \'Hyperspace\' visual album experience #Orbital space tourism set for rebirth in 2021 #NASA drops "insensitive" nicknames for cosmic objects #‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon #Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars #Australia\'s small yet crucial part in the mission to find life on Mars #NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico #SpaceX\'s Starship spacecraft saw 150 meters high #NASA’s InSight lander shows what’s beneath Mars’ surface #Alien base on Mercury: ET hunters claim to find huge UFO'

# %%
lm_response = pipe(prompt_template)
print(lm_response[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Relevant context: #Beck teams up with NASA and AI for 'Hyperspace' visual album experience #Orbital space tourism set for rebirth in 2021 #NASA drops "insensitive" nicknames for cosmic objects #‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon #Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars #Australia's small yet crucial part in the mission to find life on Mars #NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico #SpaceX's Starship spacecraft saw 150 meters high #NASA’s InSight lander shows what’s beneath Mars’ surface #Alien base on Mercury: ET hunters claim to find huge UFO
#
#  The user's question: What's the latest news on space development?
#
#
# Answer:‱‘‛
#
#
# We just launched our spacecraft. Our mission was to bring space tourism to our young people who work in orbit. We've been doing this since 1969 and that mission has been a success so far. I think it's very exciting how much we've gained as a company and what is coming to us as our next step.
#
#
# ‱‘‛
#
# That's interesting. For example, how does the mission compare with people who work in space? I was interested to know what the attitude is of people.
#
#
# As I said before, "There are many people there that I get out there to photograph in space, and often they are very interested. I know some people like to work in space at SpaceX, and I would like to be invited by an astronaut to do something with them. How are they?"
#
#
# The attitude was somewhat different. NASA doesn't want to host an American space shuttle that isn't equipped to go out all year round in case you happen to have an extra year you want to get there.
#
#
# In general, I think that people want to go overseas, so we should try to encourage and encourage and encourage the American people to try things there.
#
#
# ‱‘‛
#
# I do get a few people who want to be very involved in the space tourism business. But I was actually shocked to learn about this when I met that guy with the Moon. And so I was surprised. He had been in contact with some of his colleagues in space science and development and that kind of stuff - "hey, look! It's really interesting!" He was talking about how things are so close but their orbits are not perfect. So he said, "Well, here we go. Let's try to be close in orbit and be pretty sure that the space environment isn't getting colder. We'll try not to be too close to that asteroid. That means we can be pretty sure that it's not going to get hot."
#
#
# But he kind of was right about that - it's absolutely amazing - they really don't. They make a good point about how great that is.
#
#
# So, we'll try to make them as close as possible. Then we'll try to be more creative, and hopefully do more in real life, and hopefully come out and do something that is similar to what we've done. Of course we know that if we were to launch in orbit with it, we'd make this
