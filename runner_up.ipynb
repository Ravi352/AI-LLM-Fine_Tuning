# %%
import random 
n=int(input("Enter the number you want in the list: "))
arr=[]
for i in range(n): 
   arr.append(random.randint(-100,100))
print(arr)
b=max(arr)
print(b)
arr.remove(b)
print(max(arr))
# Out:
# Enter the number you want in the list: 40
# [-33, 16, 68, -90, 95, 84, -96, -54, 73, -13, -71, -79, 70, 21, 76, 94, -98, 86, 40, -17, -97, -72, -47, -77, 87, 35, 6, -77, -36, -48, 26, 87, 14, 87, 2, -18, 89, -22, -35, -98]
# 95
# 94

# %%
n = int(input())
arr = map(int, input().split())
if max(arr) in arr:
    first_max=max(arr)
    #arr.remove(first_max)
second_max=max(arr)
print(second_max)
# Out:
# 5
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-58bde087dd51> in <module>()
#       4     first_max=max(arr)
#       5     #arr.remove(first_max)
# ----> 6 second_max=max(arr)
#       7 print(second_max)
#       8
#
# ValueError: max() arg is an empty sequence

# %%
2
